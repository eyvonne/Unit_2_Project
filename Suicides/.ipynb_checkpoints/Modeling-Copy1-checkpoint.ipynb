# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_profiling
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
import category_encoders as ce
from sklearn.linear_model import LinearRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from pdpbox.pdp import pdp_isolate, pdp_plot
from pdpbox.pdp import pdp_interact, pdp_interact_plot
from xgboost import XGBRegressor
import shap

# %%
df= pd.read_csv('master.csv')

# %%
df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# max        0.944000       126352.000000

# %% [markdown]
# This code splits them up by the year and I think I like the split

# %%
def cleanUp(df):
    df['annual_gdp']=df[' gdp_for_year ($) '].str.replace(',','')
    
    df=df.drop([' gdp_for_year ($) ','country-year', 'suicides_no'], axis=1)
    df['annual_gdp']=df['annual_gdp'].astype(int)
    
    countrySer=df.groupby('country')["HDI for year"].mean()
    def HDIcleanup(data):
        country=data[0]
        HDI=data[1]
        if np.isnan(HDI):       
            return countrySer[country]
        else:
            return HDI
    df['HDI_for_year']=df[['country','HDI for year']].apply(HDIcleanup,axis=1)
    df=df.drop('HDI for year', axis=1)
    df=df.dropna()
    y=df[['year','suicides/100k pop']]
    df=df.drop('suicides/100k pop',axis=1)
    return df, y

# %%
df, y=cleanUp(df)

# %%
df.head()
# Out:
#    country  year     sex          age  population  gdp_per_capita ($)  \
# 0  Albania  1987    male  15-24 years      312900                 796
# 1  Albania  1987    male  35-54 years      308000                 796
# 2  Albania  1987  female  15-24 years      289700                 796
# 3  Albania  1987    male    75+ years       21800                 796
# 4  Albania  1987    male  25-34 years      274300                 796
#
#         generation  annual_gdp  HDI_for_year
# 0     Generation X  2156624900         0.673
# 1           Silent  2156624900         0.673
# 2     Generation X  2156624900         0.673
# 3  G.I. Generation  2156624900         0.673
# 4          Boomers  2156624900         0.673

# %%
df.groupby('country')['HDI_for_year'].mean().mean()
# Out:
# 0.7677165432098767

# %%
df.HDI_for_year.median()
# Out:
# 0.7795999999999998

# %%
X_train=df[df['year']<2005]
X_val=df[(df['year']>=2005) & (df['year']<2010)]
X_test=df[df['year']>=2010]
y_train=y[y['year']<2005]['suicides/100k pop']
y_val=y[(y['year']>=2005) & (y['year']<2010)]['suicides/100k pop']
y_test=y[y['year']>=2010]['suicides/100k pop']
X_train.shape, X_val.shape, X_test.shape,y_train.shape,y_val.shape,y_test.shape
# Out:
# ((15840, 9), (4896, 9), (5598, 9), (15840,), (4896,), (5598,))

# %%
#begin with mean baseline
y_train.mean()
y_pred=np.full_like(y_train, y_train.mean())
mean_absolute_error(y_train, y_pred)
# Out:
# 13.089125216416058

# %%
encoder=ce.OrdinalEncoder()
modelXG=XGBRegressor(n_estimators=5000, learning_rate=.5, n_jobs=-1)

# %%
X_train_enc=encoder.fit_transform(X_train)
X_val_enc=encoder.transform(X_val)
X_test_enc=encoder.transform(X_test)

evals=[(X_train_enc,y_train),(X_val_enc, y_val)]

modelXG.fit(X_train_enc, y_train, eval_set=evals, early_stopping_rounds=50, eval_metric='mae')
# Out:
# [10:24:59] WARNING: /usr/local/miniconda/conda-bld/xgboost_1566327371504/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:9.18259	validation_1-mae:7.78217
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 50 rounds.
# [1]	validation_0-mae:8.71287	validation_1-mae:7.84384
# [2]	validation_0-mae:8.71392	validation_1-mae:8.08816
# [3]	validation_0-mae:8.57014	validation_1-mae:8.32094
# [4]	validation_0-mae:8.39927	validation_1-mae:8.32223
# [5]	validation_0-mae:8.25159	validation_1-mae:8.40392
# [6]	validation_0-mae:8.1607	validation_1-mae:8.2101
# [7]	validation_0-mae:8.03106	validation_1-mae:8.06729
# [8]	validation_0-mae:7.98827	validation_1-mae:8.06518
# [9]	validation_0-mae:7.82457	validation_1-mae:7.96504
# [10]	validation_0-mae:7.72625	validation_1-mae:7.74915
# [11]	validation_0-mae:7.65151	validation_1-mae:7.7346
# [12]	validation_0-mae:7.59737	validation_1-mae:7.67321
# [13]	validation_0-mae:7.48818	validation_1-mae:7.593
# [14]	validation_0-mae:7.48549	validation_1-mae:7.60475
# [15]	validation_0-mae:7.44655	validation_1-mae:7.56305
# [16]	validation_0-mae:7.41404	validation_1-mae:7.66022
# [17]	validation_0-mae:7.37169	validation_1-mae:7.52602
# [18]	validation_0-mae:7.27333	validation_1-mae:7.42915
# [19]	validation_0-mae:7.19852	validation_1-mae:7.4062
# [20]	validation_0-mae:7.20468	validation_1-mae:7.45513
# [21]	validation_0-mae:7.10521	validation_1-mae:7.31876
# [22]	validation_0-mae:7.0791	validation_1-mae:7.2762
# [23]	validation_0-mae:7.00464	validation_1-mae:7.24558
# [24]	validation_0-mae:6.9873	validation_1-mae:7.20899
# [25]	validation_0-mae:6.9261	validation_1-mae:7.28726
# [26]	validation_0-mae:6.87965	validation_1-mae:7.24279
# [27]	validation_0-mae:6.8642	validation_1-mae:7.24053
# [28]	validation_0-mae:6.84961	validation_1-mae:7.23293
# [29]	validation_0-mae:6.82852	validation_1-mae:7.25942
# [30]	validation_0-mae:6.79349	validation_1-mae:7.30609
# [31]	validation_0-mae:6.75539	validation_1-mae:7.26673
# [32]	validation_0-mae:6.72294	validation_1-mae:7.268
# [33]	validation_0-mae:6.71594	validation_1-mae:7.2634
# [34]	validation_0-mae:6.71049	validation_1-mae:7.2853
# [35]	validation_0-mae:6.68246	validation_1-mae:7.29219
# [36]	validation_0-mae:6.66437	validation_1-mae:7.28503
# [37]	validation_0-mae:6.63866	validation_1-mae:7.30688
# [38]	validation_0-mae:6.6268	validation_1-mae:7.29498
# [39]	validation_0-mae:6.62408	validation_1-mae:7.30131
# [40]	validation_0-mae:6.57535	validation_1-mae:7.28055
# [41]	validation_0-mae:6.5836	validation_1-mae:7.29024
# [42]	validation_0-mae:6.55548	validation_1-mae:7.29598
# [43]	validation_0-mae:6.54812	validation_1-mae:7.30161
# [44]	validation_0-mae:6.53027	validation_1-mae:7.28294
# [45]	validation_0-mae:6.45977	validation_1-mae:7.22999
# [46]	validation_0-mae:6.44846	validation_1-mae:7.22068
# [47]	validation_0-mae:6.4134	validation_1-mae:7.21435
# [48]	validation_0-mae:6.36773	validation_1-mae:7.18305
# [49]	validation_0-mae:6.35193	validation_1-mae:7.1936
# [50]	validation_0-mae:6.33024	validation_1-mae:7.17827
# [51]	validation_0-mae:6.31827	validation_1-mae:7.17631
# [52]	validation_0-mae:6.29423	validation_1-mae:7.17588
# [53]	validation_0-mae:6.27497	validation_1-mae:7.16288
# [54]	validation_0-mae:6.26965	validation_1-mae:7.15879
# [55]	validation_0-mae:6.24333	validation_1-mae:7.1387
# [56]	validation_0-mae:6.237	validation_1-mae:7.15545
# [57]	validation_0-mae:6.20566	validation_1-mae:7.15171
# [58]	validation_0-mae:6.20342	validation_1-mae:7.15665
# [59]	validation_0-mae:6.18819	validation_1-mae:7.13389
# [60]	validation_0-mae:6.16931	validation_1-mae:7.11768
# [61]	validation_0-mae:6.15059	validation_1-mae:7.1187
# [62]	validation_0-mae:6.13769	validation_1-mae:7.10872
# [63]	validation_0-mae:6.12208	validation_1-mae:7.10376
# [64]	validation_0-mae:6.10133	validation_1-mae:7.09693
# [65]	validation_0-mae:6.06149	validation_1-mae:7.10541
# [66]	validation_0-mae:6.03352	validation_1-mae:7.10589
# [67]	validation_0-mae:6.019	validation_1-mae:7.1049
# [68]	validation_0-mae:5.99936	validation_1-mae:7.06592
# [69]	validation_0-mae:5.98587	validation_1-mae:7.07511
# [70]	validation_0-mae:5.97786	validation_1-mae:7.0926
# [71]	validation_0-mae:5.96344	validation_1-mae:7.07817
# [72]	validation_0-mae:5.9481	validation_1-mae:7.08254
# [73]	validation_0-mae:5.94034	validation_1-mae:7.06732
# [74]	validation_0-mae:5.9341	validation_1-mae:7.06396
# [75]	validation_0-mae:5.92613	validation_1-mae:7.10515
# [76]	validation_0-mae:5.90604	validation_1-mae:7.06303
# [77]	validation_0-mae:5.8961	validation_1-mae:7.06491
# [78]	validation_0-mae:5.86852	validation_1-mae:7.08766
# [79]	validation_0-mae:5.85464	validation_1-mae:7.08819
# [80]	validation_0-mae:5.84556	validation_1-mae:7.0839
# [81]	validation_0-mae:5.84659	validation_1-mae:7.08015
# [82]	validation_0-mae:5.8285	validation_1-mae:7.07707
# [83]	validation_0-mae:5.82459	validation_1-mae:7.07683
# [84]	validation_0-mae:5.80573	validation_1-mae:7.07752
# [85]	validation_0-mae:5.7933	validation_1-mae:7.06621
# [86]	validation_0-mae:5.78344	validation_1-mae:7.1032
# [87]	validation_0-mae:5.7712	validation_1-mae:7.11484
# [88]	validation_0-mae:5.76788	validation_1-mae:7.10167
# [89]	validation_0-mae:5.7543	validation_1-mae:7.09153
# [90]	validation_0-mae:5.74876	validation_1-mae:7.09067
# [91]	validation_0-mae:5.7418	validation_1-mae:7.1046
# [92]	validation_0-mae:5.73484	validation_1-mae:7.08864
# [93]	validation_0-mae:5.73221	validation_1-mae:7.08899
# [94]	validation_0-mae:5.72301	validation_1-mae:7.08174
# [95]	validation_0-mae:5.69994	validation_1-mae:7.06359
# [96]	validation_0-mae:5.69475	validation_1-mae:7.0637
# [97]	validation_0-mae:5.68588	validation_1-mae:7.05783
# [98]	validation_0-mae:5.68218	validation_1-mae:7.04825
# [99]	validation_0-mae:5.66782	validation_1-mae:7.03454
# [100]	validation_0-mae:5.66377	validation_1-mae:7.02511
# [101]	validation_0-mae:5.65178	validation_1-mae:7.01508
# [102]	validation_0-mae:5.64173	validation_1-mae:7.014
# [103]	validation_0-mae:5.63794	validation_1-mae:7.00201
# [104]	validation_0-mae:5.62853	validation_1-mae:7.00034
# [105]	validation_0-mae:5.62174	validation_1-mae:7.00599
# [106]	validation_0-mae:5.61603	validation_1-mae:7.00513
# [107]	validation_0-mae:5.61	validation_1-mae:6.99669
# [108]	validation_0-mae:5.60422	validation_1-mae:6.99794
# [109]	validation_0-mae:5.54202	validation_1-mae:6.95545
# [110]	validation_0-mae:5.53134	validation_1-mae:6.95794
# [111]	validation_0-mae:5.53038	validation_1-mae:6.95309
# [112]	validation_0-mae:5.51248	validation_1-mae:6.93041
# [113]	validation_0-mae:5.50914	validation_1-mae:6.941
# [114]	validation_0-mae:5.50309	validation_1-mae:6.93626
# [115]	validation_0-mae:5.49554	validation_1-mae:6.9497
# [116]	validation_0-mae:5.48965	validation_1-mae:6.95
# [117]	validation_0-mae:5.48201	validation_1-mae:6.95409
# [118]	validation_0-mae:5.47633	validation_1-mae:6.95105
# [119]	validation_0-mae:5.47413	validation_1-mae:6.95113
# [120]	validation_0-mae:5.46901	validation_1-mae:6.96286
# [121]	validation_0-mae:5.45651	validation_1-mae:6.94981
# [122]	validation_0-mae:5.44629	validation_1-mae:6.94532
# [123]	validation_0-mae:5.43706	validation_1-mae:6.95225
# [124]	validation_0-mae:5.43556	validation_1-mae:6.95919
# [125]	validation_0-mae:5.42246	validation_1-mae:6.95343
# [126]	validation_0-mae:5.40911	validation_1-mae:6.93498
# [127]	validation_0-mae:5.39321	validation_1-mae:6.94338
# [128]	validation_0-mae:5.38536	validation_1-mae:6.92338
# [129]	validation_0-mae:5.38173	validation_1-mae:6.91659
# [130]	validation_0-mae:5.37647	validation_1-mae:6.9174
# [131]	validation_0-mae:5.36098	validation_1-mae:6.91604
# [132]	validation_0-mae:5.35098	validation_1-mae:6.9202
# [133]	validation_0-mae:5.3438	validation_1-mae:6.91237
# [134]	validation_0-mae:5.32164	validation_1-mae:6.89971
# [135]	validation_0-mae:5.31617	validation_1-mae:6.90097
# [136]	validation_0-mae:5.29422	validation_1-mae:6.89956
# [137]	validation_0-mae:5.28495	validation_1-mae:6.90196
# [138]	validation_0-mae:5.28244	validation_1-mae:6.90589
# [139]	validation_0-mae:5.27972	validation_1-mae:6.90542
# [140]	validation_0-mae:5.27407	validation_1-mae:6.89819
# [141]	validation_0-mae:5.26243	validation_1-mae:6.90263
# [142]	validation_0-mae:5.24552	validation_1-mae:6.89735
# [143]	validation_0-mae:5.2312	validation_1-mae:6.92644
# [144]	validation_0-mae:5.22105	validation_1-mae:6.91666
# [145]	validation_0-mae:5.21961	validation_1-mae:6.92636
# [146]	validation_0-mae:5.21037	validation_1-mae:6.94235
# [147]	validation_0-mae:5.20304	validation_1-mae:6.94135
# [148]	validation_0-mae:5.20007	validation_1-mae:6.94127
# [149]	validation_0-mae:5.19736	validation_1-mae:6.93756
# [150]	validation_0-mae:5.19049	validation_1-mae:6.92762
# [151]	validation_0-mae:5.18755	validation_1-mae:6.92652
# [152]	validation_0-mae:5.18308	validation_1-mae:6.92253
# [153]	validation_0-mae:5.18095	validation_1-mae:6.90951
# [154]	validation_0-mae:5.17663	validation_1-mae:6.90278
# [155]	validation_0-mae:5.1738	validation_1-mae:6.90395
# [156]	validation_0-mae:5.1695	validation_1-mae:6.92639
# [157]	validation_0-mae:5.16491	validation_1-mae:6.92625
# [158]	validation_0-mae:5.16544	validation_1-mae:6.92137
# [159]	validation_0-mae:5.15726	validation_1-mae:6.91868
# [160]	validation_0-mae:5.15181	validation_1-mae:6.91773
# [161]	validation_0-mae:5.14852	validation_1-mae:6.93568
# [162]	validation_0-mae:5.14419	validation_1-mae:6.93554
# [163]	validation_0-mae:5.13688	validation_1-mae:6.93227
# [164]	validation_0-mae:5.13406	validation_1-mae:6.93372
# [165]	validation_0-mae:5.12206	validation_1-mae:6.93492
# [166]	validation_0-mae:5.1177	validation_1-mae:6.92164
# [167]	validation_0-mae:5.11474	validation_1-mae:6.92426
# [168]	validation_0-mae:5.11354	validation_1-mae:6.92131
# [169]	validation_0-mae:5.1128	validation_1-mae:6.92168
# [170]	validation_0-mae:5.1072	validation_1-mae:6.93862
# [171]	validation_0-mae:5.10268	validation_1-mae:6.93135
# [172]	validation_0-mae:5.07792	validation_1-mae:6.92887
# [173]	validation_0-mae:5.07218	validation_1-mae:6.91633
# [174]	validation_0-mae:5.06706	validation_1-mae:6.91523
# [175]	validation_0-mae:5.06176	validation_1-mae:6.91666
# [176]	validation_0-mae:5.0548	validation_1-mae:6.91631
# [177]	validation_0-mae:5.04523	validation_1-mae:6.90708
# [178]	validation_0-mae:5.03604	validation_1-mae:6.90595
# [179]	validation_0-mae:5.03011	validation_1-mae:6.90231
# [180]	validation_0-mae:5.01671	validation_1-mae:6.89037
# [181]	validation_0-mae:5.00277	validation_1-mae:6.8836
# [182]	validation_0-mae:4.99146	validation_1-mae:6.85648
# [183]	validation_0-mae:4.97773	validation_1-mae:6.84081
# [184]	validation_0-mae:4.97435	validation_1-mae:6.83598
# [185]	validation_0-mae:4.96932	validation_1-mae:6.83547
# [186]	validation_0-mae:4.96364	validation_1-mae:6.8437
# [187]	validation_0-mae:4.94329	validation_1-mae:6.84661
# [188]	validation_0-mae:4.93981	validation_1-mae:6.84696
# [189]	validation_0-mae:4.92949	validation_1-mae:6.83244
# [190]	validation_0-mae:4.92418	validation_1-mae:6.82017
# [191]	validation_0-mae:4.91386	validation_1-mae:6.81578
# [192]	validation_0-mae:4.90983	validation_1-mae:6.8028
# [193]	validation_0-mae:4.89769	validation_1-mae:6.7725
# [194]	validation_0-mae:4.89006	validation_1-mae:6.77446
# [195]	validation_0-mae:4.88526	validation_1-mae:6.77076
# [196]	validation_0-mae:4.87779	validation_1-mae:6.78114
# [197]	validation_0-mae:4.87649	validation_1-mae:6.78112
# [198]	validation_0-mae:4.87379	validation_1-mae:6.78352
# [199]	validation_0-mae:4.86665	validation_1-mae:6.78307
# [200]	validation_0-mae:4.86477	validation_1-mae:6.78377
# [201]	validation_0-mae:4.86098	validation_1-mae:6.78436
# [202]	validation_0-mae:4.85714	validation_1-mae:6.788
# [203]	validation_0-mae:4.84675	validation_1-mae:6.78358
# [204]	validation_0-mae:4.84373	validation_1-mae:6.7799
# [205]	validation_0-mae:4.82538	validation_1-mae:6.76089
# [206]	validation_0-mae:4.82016	validation_1-mae:6.76311
# [207]	validation_0-mae:4.81973	validation_1-mae:6.76789
# [208]	validation_0-mae:4.81691	validation_1-mae:6.76681
# [209]	validation_0-mae:4.81597	validation_1-mae:6.76816
# [210]	validation_0-mae:4.81034	validation_1-mae:6.76692
# [211]	validation_0-mae:4.80547	validation_1-mae:6.76726
# [212]	validation_0-mae:4.80457	validation_1-mae:6.74806
# [213]	validation_0-mae:4.80039	validation_1-mae:6.75163
# [214]	validation_0-mae:4.79885	validation_1-mae:6.75182
# [215]	validation_0-mae:4.79742	validation_1-mae:6.75082
# [216]	validation_0-mae:4.79476	validation_1-mae:6.74907
# [217]	validation_0-mae:4.78586	validation_1-mae:6.74507
# [218]	validation_0-mae:4.78117	validation_1-mae:6.7419
# [219]	validation_0-mae:4.77731	validation_1-mae:6.73145
# [220]	validation_0-mae:4.76714	validation_1-mae:6.73268
# [221]	validation_0-mae:4.76432	validation_1-mae:6.74067
# [222]	validation_0-mae:4.76137	validation_1-mae:6.73608
# [223]	validation_0-mae:4.75502	validation_1-mae:6.73103
# [224]	validation_0-mae:4.75251	validation_1-mae:6.7291
# [225]	validation_0-mae:4.74854	validation_1-mae:6.74081
# [226]	validation_0-mae:4.74123	validation_1-mae:6.73408
# [227]	validation_0-mae:4.7396	validation_1-mae:6.73402
# [228]	validation_0-mae:4.73714	validation_1-mae:6.72956
# [229]	validation_0-mae:4.7271	validation_1-mae:6.72829
# [230]	validation_0-mae:4.72139	validation_1-mae:6.72086
# [231]	validation_0-mae:4.71482	validation_1-mae:6.7147
# [232]	validation_0-mae:4.70782	validation_1-mae:6.71291
# [233]	validation_0-mae:4.7011	validation_1-mae:6.72193
# [234]	validation_0-mae:4.69714	validation_1-mae:6.72278
# [235]	validation_0-mae:4.69319	validation_1-mae:6.72014
# [236]	validation_0-mae:4.69267	validation_1-mae:6.72397
# [237]	validation_0-mae:4.68932	validation_1-mae:6.73026
# [238]	validation_0-mae:4.68592	validation_1-mae:6.73404
# [239]	validation_0-mae:4.68472	validation_1-mae:6.7358
# [240]	validation_0-mae:4.67915	validation_1-mae:6.7327
# [241]	validation_0-mae:4.67387	validation_1-mae:6.7294
# [242]	validation_0-mae:4.66735	validation_1-mae:6.72156
# [243]	validation_0-mae:4.66123	validation_1-mae:6.71165
# [244]	validation_0-mae:4.657	validation_1-mae:6.71329
# [245]	validation_0-mae:4.65289	validation_1-mae:6.70932
# [246]	validation_0-mae:4.65041	validation_1-mae:6.70901
# [247]	validation_0-mae:4.64187	validation_1-mae:6.71052
# [248]	validation_0-mae:4.63931	validation_1-mae:6.7086
# [249]	validation_0-mae:4.6353	validation_1-mae:6.71076
# [250]	validation_0-mae:4.63043	validation_1-mae:6.70687
# [251]	validation_0-mae:4.62783	validation_1-mae:6.70614
# [252]	validation_0-mae:4.62343	validation_1-mae:6.70602
# [253]	validation_0-mae:4.61547	validation_1-mae:6.69841
# [254]	validation_0-mae:4.60669	validation_1-mae:6.70337
# [255]	validation_0-mae:4.6051	validation_1-mae:6.70737
# [256]	validation_0-mae:4.59654	validation_1-mae:6.69333
# [257]	validation_0-mae:4.59071	validation_1-mae:6.70566
# [258]	validation_0-mae:4.58906	validation_1-mae:6.70124
# [259]	validation_0-mae:4.58925	validation_1-mae:6.70331
# [260]	validation_0-mae:4.58331	validation_1-mae:6.71472
# [261]	validation_0-mae:4.57991	validation_1-mae:6.71178
# [262]	validation_0-mae:4.57537	validation_1-mae:6.71065
# [263]	validation_0-mae:4.57137	validation_1-mae:6.71355
# [264]	validation_0-mae:4.56743	validation_1-mae:6.70721
# [265]	validation_0-mae:4.56517	validation_1-mae:6.70685
# [266]	validation_0-mae:4.56346	validation_1-mae:6.70492
# [267]	validation_0-mae:4.56227	validation_1-mae:6.70986
# [268]	validation_0-mae:4.55532	validation_1-mae:6.70931
# [269]	validation_0-mae:4.55373	validation_1-mae:6.70976
# [270]	validation_0-mae:4.5519	validation_1-mae:6.70991
# [271]	validation_0-mae:4.55066	validation_1-mae:6.70958
# [272]	validation_0-mae:4.55136	validation_1-mae:6.70972
# [273]	validation_0-mae:4.54919	validation_1-mae:6.70911
# [274]	validation_0-mae:4.54365	validation_1-mae:6.717
# [275]	validation_0-mae:4.54132	validation_1-mae:6.71706
# [276]	validation_0-mae:4.5363	validation_1-mae:6.70754
# [277]	validation_0-mae:4.53014	validation_1-mae:6.69377
# [278]	validation_0-mae:4.52503	validation_1-mae:6.69272
# [279]	validation_0-mae:4.51833	validation_1-mae:6.69111
# [280]	validation_0-mae:4.51268	validation_1-mae:6.79115
# [281]	validation_0-mae:4.50968	validation_1-mae:6.79292
# [282]	validation_0-mae:4.50476	validation_1-mae:6.77756
# [283]	validation_0-mae:4.5018	validation_1-mae:6.77713
# [284]	validation_0-mae:4.49783	validation_1-mae:6.77695
# [285]	validation_0-mae:4.49542	validation_1-mae:6.77935
# [286]	validation_0-mae:4.49425	validation_1-mae:6.78056
# [287]	validation_0-mae:4.4807	validation_1-mae:6.78265
# [288]	validation_0-mae:4.47035	validation_1-mae:6.77739
# [289]	validation_0-mae:4.46567	validation_1-mae:6.78038
# [290]	validation_0-mae:4.46182	validation_1-mae:6.77205
# [291]	validation_0-mae:4.45837	validation_1-mae:6.76835
# [292]	validation_0-mae:4.45375	validation_1-mae:6.76481
# [293]	validation_0-mae:4.45144	validation_1-mae:6.75803
# [294]	validation_0-mae:4.4497	validation_1-mae:6.75437
# [295]	validation_0-mae:4.4472	validation_1-mae:6.75538
# [296]	validation_0-mae:4.44297	validation_1-mae:6.75583
# [297]	validation_0-mae:4.43736	validation_1-mae:6.74991
# [298]	validation_0-mae:4.43471	validation_1-mae:6.74982
# [299]	validation_0-mae:4.43259	validation_1-mae:6.72985
# [300]	validation_0-mae:4.42787	validation_1-mae:6.73389
# [301]	validation_0-mae:4.42504	validation_1-mae:6.72988
# [302]	validation_0-mae:4.4174	validation_1-mae:6.72321
# [303]	validation_0-mae:4.41556	validation_1-mae:6.72455
# [304]	validation_0-mae:4.40149	validation_1-mae:6.70894
# [305]	validation_0-mae:4.39944	validation_1-mae:6.71041
# [306]	validation_0-mae:4.39488	validation_1-mae:6.70197
# [307]	validation_0-mae:4.39424	validation_1-mae:6.70364
# [308]	validation_0-mae:4.39289	validation_1-mae:6.70397
# [309]	validation_0-mae:4.38627	validation_1-mae:6.70233
# [310]	validation_0-mae:4.38209	validation_1-mae:6.69948
# [311]	validation_0-mae:4.38192	validation_1-mae:6.69247
# [312]	validation_0-mae:4.37799	validation_1-mae:6.69177
# [313]	validation_0-mae:4.37625	validation_1-mae:6.69711
# [314]	validation_0-mae:4.37353	validation_1-mae:6.71608
# [315]	validation_0-mae:4.37097	validation_1-mae:6.71433
# [316]	validation_0-mae:4.36965	validation_1-mae:6.71503
# [317]	validation_0-mae:4.36567	validation_1-mae:6.71681
# [318]	validation_0-mae:4.35574	validation_1-mae:6.70034
# [319]	validation_0-mae:4.35208	validation_1-mae:6.69862
# [320]	validation_0-mae:4.35107	validation_1-mae:6.69882
# [321]	validation_0-mae:4.3489	validation_1-mae:6.69923
# [322]	validation_0-mae:4.348	validation_1-mae:6.69916
# [323]	validation_0-mae:4.34409	validation_1-mae:6.7017
# [324]	validation_0-mae:4.34138	validation_1-mae:6.70438
# [325]	validation_0-mae:4.3358	validation_1-mae:6.70408
# [326]	validation_0-mae:4.31125	validation_1-mae:6.6781
# [327]	validation_0-mae:4.31163	validation_1-mae:6.68056
# [328]	validation_0-mae:4.30941	validation_1-mae:6.68047
# [329]	validation_0-mae:4.29981	validation_1-mae:6.67155
# [330]	validation_0-mae:4.29389	validation_1-mae:6.67007
# [331]	validation_0-mae:4.2909	validation_1-mae:6.67195
# [332]	validation_0-mae:4.28801	validation_1-mae:6.67507
# [333]	validation_0-mae:4.28353	validation_1-mae:6.67905
# [334]	validation_0-mae:4.27925	validation_1-mae:6.67435
# [335]	validation_0-mae:4.27428	validation_1-mae:6.67517
# [336]	validation_0-mae:4.27191	validation_1-mae:6.67549
# [337]	validation_0-mae:4.26998	validation_1-mae:6.67194
# [338]	validation_0-mae:4.26861	validation_1-mae:6.67288
# [339]	validation_0-mae:4.26609	validation_1-mae:6.67856
# [340]	validation_0-mae:4.26525	validation_1-mae:6.67762
# [341]	validation_0-mae:4.26319	validation_1-mae:6.67607
# [342]	validation_0-mae:4.25973	validation_1-mae:6.67088
# [343]	validation_0-mae:4.25801	validation_1-mae:6.67262
# [344]	validation_0-mae:4.2558	validation_1-mae:6.67661
# [345]	validation_0-mae:4.25281	validation_1-mae:6.67826
# [346]	validation_0-mae:4.24808	validation_1-mae:6.67186
# [347]	validation_0-mae:4.24402	validation_1-mae:6.6658
# [348]	validation_0-mae:4.24097	validation_1-mae:6.66317
# [349]	validation_0-mae:4.23853	validation_1-mae:6.66298
# [350]	validation_0-mae:4.23669	validation_1-mae:6.66245
# [351]	validation_0-mae:4.23591	validation_1-mae:6.6622
# [352]	validation_0-mae:4.23364	validation_1-mae:6.66125
# [353]	validation_0-mae:4.23115	validation_1-mae:6.65945
# [354]	validation_0-mae:4.23025	validation_1-mae:6.66155
# [355]	validation_0-mae:4.22637	validation_1-mae:6.67909
# [356]	validation_0-mae:4.22135	validation_1-mae:6.68082
# [357]	validation_0-mae:4.21941	validation_1-mae:6.68037
# [358]	validation_0-mae:4.21616	validation_1-mae:6.68013
# [359]	validation_0-mae:4.21343	validation_1-mae:6.68134
# [360]	validation_0-mae:4.21195	validation_1-mae:6.68561
# [361]	validation_0-mae:4.20906	validation_1-mae:6.67877
# [362]	validation_0-mae:4.20429	validation_1-mae:6.67881
# [363]	validation_0-mae:4.20287	validation_1-mae:6.67733
# [364]	validation_0-mae:4.20031	validation_1-mae:6.68158
# [365]	validation_0-mae:4.19706	validation_1-mae:6.68101
# [366]	validation_0-mae:4.19364	validation_1-mae:6.67559
# [367]	validation_0-mae:4.18171	validation_1-mae:6.66261
# [368]	validation_0-mae:4.17968	validation_1-mae:6.66551
# [369]	validation_0-mae:4.17656	validation_1-mae:6.6672
# [370]	validation_0-mae:4.16804	validation_1-mae:6.64679
# [371]	validation_0-mae:4.16396	validation_1-mae:6.64381
# [372]	validation_0-mae:4.16328	validation_1-mae:6.64142
# [373]	validation_0-mae:4.16138	validation_1-mae:6.64105
# [374]	validation_0-mae:4.15823	validation_1-mae:6.64295
# [375]	validation_0-mae:4.15477	validation_1-mae:6.63902
# [376]	validation_0-mae:4.1519	validation_1-mae:6.64634
# [377]	validation_0-mae:4.14493	validation_1-mae:6.64597
# [378]	validation_0-mae:4.14354	validation_1-mae:6.6466
# [379]	validation_0-mae:4.14106	validation_1-mae:6.64199
# [380]	validation_0-mae:4.13945	validation_1-mae:6.64175
# [381]	validation_0-mae:4.13564	validation_1-mae:6.63793
# [382]	validation_0-mae:4.13399	validation_1-mae:6.63214
# [383]	validation_0-mae:4.1318	validation_1-mae:6.63237
# [384]	validation_0-mae:4.12927	validation_1-mae:6.63007
# [385]	validation_0-mae:4.12668	validation_1-mae:6.62963
# [386]	validation_0-mae:4.12569	validation_1-mae:6.62943
# [387]	validation_0-mae:4.12318	validation_1-mae:6.62748
# [388]	validation_0-mae:4.11866	validation_1-mae:6.6299
# [389]	validation_0-mae:4.11549	validation_1-mae:6.63229
# [390]	validation_0-mae:4.11465	validation_1-mae:6.63379
# [391]	validation_0-mae:4.11229	validation_1-mae:6.64695
# [392]	validation_0-mae:4.10754	validation_1-mae:6.64758
# [393]	validation_0-mae:4.10406	validation_1-mae:6.65137
# [394]	validation_0-mae:4.10209	validation_1-mae:6.6521
# [395]	validation_0-mae:4.10013	validation_1-mae:6.65192
# [396]	validation_0-mae:4.09443	validation_1-mae:6.64634
# [397]	validation_0-mae:4.09216	validation_1-mae:6.65369
# [398]	validation_0-mae:4.08906	validation_1-mae:6.6589
# [399]	validation_0-mae:4.0847	validation_1-mae:6.66166
# [400]	validation_0-mae:4.07777	validation_1-mae:6.65759
# [401]	validation_0-mae:4.07615	validation_1-mae:6.65862
# [402]	validation_0-mae:4.07478	validation_1-mae:6.66105
# [403]	validation_0-mae:4.07237	validation_1-mae:6.66209
# [404]	validation_0-mae:4.07066	validation_1-mae:6.6619
# [405]	validation_0-mae:4.07004	validation_1-mae:6.66214
# [406]	validation_0-mae:4.06945	validation_1-mae:6.6576
# [407]	validation_0-mae:4.06686	validation_1-mae:6.65675
# [408]	validation_0-mae:4.06153	validation_1-mae:6.65259
# [409]	validation_0-mae:4.05685	validation_1-mae:6.65059
# [410]	validation_0-mae:4.05372	validation_1-mae:6.64698
# [411]	validation_0-mae:4.05137	validation_1-mae:6.64633
# [412]	validation_0-mae:4.04889	validation_1-mae:6.64401
# [413]	validation_0-mae:4.04289	validation_1-mae:6.65016
# [414]	validation_0-mae:4.04034	validation_1-mae:6.65109
# [415]	validation_0-mae:4.03743	validation_1-mae:6.64002
# [416]	validation_0-mae:4.03327	validation_1-mae:6.6419
# [417]	validation_0-mae:4.02914	validation_1-mae:6.63407
# [418]	validation_0-mae:4.02522	validation_1-mae:6.63898
# [419]	validation_0-mae:4.02453	validation_1-mae:6.63824
# [420]	validation_0-mae:4.02208	validation_1-mae:6.63887
# [421]	validation_0-mae:4.01992	validation_1-mae:6.63831
# [422]	validation_0-mae:4.01803	validation_1-mae:6.63959
# [423]	validation_0-mae:4.01719	validation_1-mae:6.63924
# [424]	validation_0-mae:4.01623	validation_1-mae:6.64025
# [425]	validation_0-mae:4.01369	validation_1-mae:6.63717
# [426]	validation_0-mae:4.01211	validation_1-mae:6.63733
# [427]	validation_0-mae:4.01083	validation_1-mae:6.63936
# [428]	validation_0-mae:4.00665	validation_1-mae:6.63786
# [429]	validation_0-mae:3.99859	validation_1-mae:6.64723
# [430]	validation_0-mae:3.99634	validation_1-mae:6.63913
# [431]	validation_0-mae:3.99371	validation_1-mae:6.63291
# [432]	validation_0-mae:3.99203	validation_1-mae:6.64496
# [433]	validation_0-mae:3.98978	validation_1-mae:6.63758
# [434]	validation_0-mae:3.98465	validation_1-mae:6.63858
# [435]	validation_0-mae:3.98211	validation_1-mae:6.63861
# [436]	validation_0-mae:3.9791	validation_1-mae:6.6421
# [437]	validation_0-mae:3.97681	validation_1-mae:6.63975
# Stopping. Best iteration:
# [387]	validation_0-mae:4.12318	validation_1-mae:6.62748
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.5, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=5000,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
row=X_train.iloc[[6184]]
row
# Out:
#       country  year   sex          age  population  gdp_per_capita ($)  \
# 10206  Greece  2000  male  15-24 years      823264               12509
#
#          generation    annual_gdp  HDI_for_year
# 10206  Generation X  130133845771         0.799

# %%
y_train.iloc[[6184]]
# Out:
# 10206    3.77
# Name: suicides/100k pop, dtype: float64

# %%
modelXG.predict(X_train_enc).min()
# Out:
# -17.993376

# %%
explainer=shap.TreeExplainer(modelXG)
row_enc=encoder.transform(row)
shap_values= explainer.shap_values(row_enc)
modelXG.predict(row_enc)
# Out:
# array([-0.52921784], dtype=float32)

# %%
shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value,
    shap_values=shap_values, 
    features=row
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# <div id='i6G234Q45KWCCYJQR2SHU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 13.434333801269531, "outValue": -0.5292263031005859, "link": "identity", "featureNames": ["country", "year", "sex", "age", "population", "gdp_per_capita ($)", "generation", "annual_gdp", "HDI_for_year"], "features": {"0": {"effect": -7.579094886779785, "value": "Greece"}, "1": {"effect": 0.07890067994594574, "value": 2000}, "2": {"effect": 5.243950843811035, "value": "male"}, "3": {"effect": -5.247854232788086, "value": "15-24 years"}, "4": {"effect": 1.3481192588806152, "value": 823264}, "5": {"effect": -3.452592372894287, "value": 12509}, "6": {"effect": -1.4965837001800537, "value": "Generation X"}, "7": {"effect": -3.5409204959869385, "value": 130133845771}, "8": {"effect": 0.6825143098831177, "value": 0.799}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i6G234Q45KWCCYJQR2SHU')
#   );
# </script>

# %%
model=RandomForestRegressor(n_estimators=100, n_jobs=-1)
model.fit(X_train_enc, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                       oob_score=False, random_state=None, verbose=0,
#                       warm_start=False)

# %%
-cross_val_score(model,X_val_enc,y_val, cv=5, scoring='neg_mean_absolute_error').mean()
# Out:
# 8.128981447311919

# %%
model.predict(X_train_enc).min()
# Out:
# 0.0

# %%
explainer=shap.TreeExplainer(model)
row_enc=encoder.transform(row)
shap_values= explainer.shap_values(row_enc)
model.predict(row_enc)
# Out:
# array([3.9002])

# %%
shap.force_plot(
    base_value=explainer.expected_value,
    shap_values=shap_values, 
    features=row
)
# Out:
# <div id='iE9CZWIRG0OTUFUFZUTVN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 13.439103081822395, "outValue": 3.90020007001786, "link": "identity", "featureNames": ["country", "year", "sex", "age", "population", "gdp_per_capita ($)", "generation", "annual_gdp", "HDI_for_year"], "features": {"0": {"effect": -2.8501563785775934, "value": "Greece"}, "1": {"effect": -0.15397314571980394, "value": 2000}, "2": {"effect": 5.05222716073671, "value": "male"}, "3": {"effect": -4.328124460434788, "value": "15-24 years"}, "4": {"effect": -1.481350880806555, "value": 823264}, "5": {"effect": -3.331909201887563, "value": 12509}, "6": {"effect": -0.5244297415830934, "value": "Generation X"}, "7": {"effect": 0.04121606331816639, "value": 130133845771}, "8": {"effect": -1.9624024268500164, "value": 0.799}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iE9CZWIRG0OTUFUFZUTVN')
#   );
# </script>

# %%
y_pred=model.predict(X_train_enc)

# %%
y_pred.min()
# Out:
# 0.0

# %% [markdown]
# The random forest regressor is giving more accurate results because it doesn't predict values less than 0. I'm not sure why this is.

# %%
def shapPlot(row_num, model, df):
    explainer=shap.TreeExplainer(model)
    row=df.loc[[row_num]]
    row_enc=encoder.transform(row)
    shap_values= explainer.shap_values(row_enc)
    
    shap.initjs()
    
    return shap.force_plot(
        base_value=explainer.expected_value,
        shap_values=shap_values,
        features=row
    )

# %%
shapPlot(24188, model, X_train)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# <div id='iPKI0CS6760X10LCWOHOC'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 13.438067689538002, "outValue": 24.719800526872184, "link": "identity", "featureNames": ["country", "year", "sex", "age", "population", "gdp_per_capita ($)", "generation", "annual_gdp", "HDI_for_year"], "features": {"0": {"effect": 9.426754529715225, "value": "Suriname"}, "1": {"effect": -0.14559759918283188, "value": 2000}, "2": {"effect": 9.151360677029158, "value": "male"}, "3": {"effect": 4.344088599343948, "value": "35-54 years"}, "4": {"effect": 2.9571983694791357, "value": 52484}, "5": {"effect": 1.90375869641913, "value": 2129}, "6": {"effect": 0.15489308387777295, "value": "Boomers"}, "7": {"effect": -16.705989668643575, "value": 892164394}, "8": {"effect": 0.19526614929621738, "value": 0.7076666666666664}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iPKI0CS6760X10LCWOHOC')
#   );
# </script>

# %%
row_enc=encoder.transform(df.loc[[6184]])

# %%
model.predict(row_enc)
# Out:
# array([1.7867])

# %%
import eli5
from eli5.sklearn import PermutationImportance

# %%
permuter= PermutationImportance(
    model,
    scoring='neg_mean_absolute_error',
    n_iter=5
)

permuter.fit(X_train_enc, y_train)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=RandomForestRegressor(bootstrap=True,
#                                                       criterion='mse',
#                                                       max_depth=None,
#                                                       max_features='auto',
#                                                       max_leaf_nodes=None,
#                                                       min_impurity_decrease=0.0,
#                                                       min_impurity_split=None,
#                                                       min_samples_leaf=1,
#                                                       min_samples_split=2,
#                                                       min_weight_fraction_leaf=0.0,
#                                                       n_estimators=100,
#                                                       n_jobs=-1,
#                                                       oob_score=False,
#                                                       random_state=None,
#                                                       verbose=0,
#                                                       warm_start=False),
#                       n_iter=5, random_state=None, refit=True,
#                       scoring='neg_mean_absolute_error')

# %%
eli5.show_weights(
    permuter,
    top=None,
    feature_names=X_train.columns.tolist()
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 7.0407
#
#                     &plusmn; 0.2393
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sex
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 6.9348
#
#                     &plusmn; 0.1395
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 HDI_for_year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 6.6607
#
#                     &plusmn; 0.1394
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 4.8001
#
#                     &plusmn; 0.0493
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 annual_gdp
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.41%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 4.4862
#
#                     &plusmn; 0.0303
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 gdp_per_capita ($)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.74%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 4.3409
#
#                     &plusmn; 0.0901
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 country
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 4.1069
#
#                     &plusmn; 0.0413
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 population
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.2436
#
#                     &plusmn; 0.0284
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 year
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.0653
#
#                     &plusmn; 0.0152
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 generation
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# it makes a significant difference to have the suicides normalized. I need to also do this on the yearly model to see what the trends look like.

# %%
def pdpSingle(feature, model, df):
    df_enc=encoder.transform(df)
    isolated= pdp_isolate(
        model=model,
        dataset=df_enc,
        model_features=df.columns.tolist(),
        feature=feature,
        num_grid_points=200
    )
    
    return pdp_plot(isolated, feature, plot_lines=True, frac_to_plot=30)

# %%
pdpSingle('HDI_for_year', model, X_train)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x120671828>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x12ba868d0>})

# %%
pdpSingle('HDI_for_year',modelXG, X_train)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <matplotlib.axes._subplots.AxesSubplot at 0x145ceb320>,
#   'pdp_ax': <matplotlib.axes._subplots.AxesSubplot at 0x1455b49b0>})

# %%
for col in X_train.columns.tolist():
    pdpSingle(col, model, X_train)

# %% [markdown]
# I think that HDI_for_year graph is the most depressing thing I've created yet. The Human Development Index measures the standard of living in a country, the closer to one it is the better the standard of living. The PDP shows that generally, as the HDI goes up, so does the rate of suicides per 100k

# %%
y_pred=model.predict(X_train_enc)

# %%
(y_pred==0).sum()
# Out:
# 553

# %%
X_train_enc['prediction']=y_pred
X_train_enc['actual']=y_train

# %%
X_train_enc[X_train_enc['actual']-X_train_enc['prediction']>0].shape, X_train_enc[X_train_enc['actual']-X_train_enc['prediction']<0].shape
# Out:
# ((6363, 11), (8923, 11))

# %% [markdown]
# The model tends to predict values that are lower than the actual values

# %%
shapPlot(10471, model, X_train)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...
# <div id='iCN2FMVD1H9PZY6Z8ZNVV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 13.438067689538002, "outValue": -7.949719638133956e-08, "link": "identity", "featureNames": ["country", "year", "sex", "age", "population", "gdp_per_capita ($)", "generation", "annual_gdp", "HDI_for_year"], "features": {"0": {"effect": -0.5795267469087881, "value": "Grenada"}, "1": {"effect": 0.12316019967451806, "value": 1993}, "2": {"effect": -3.784578755370824, "value": "female"}, "3": {"effect": -7.426445478858155, "value": "5-14 years"}, "4": {"effect": -0.2748850608709976, "value": 12426}, "5": {"effect": 0.7432116616395619, "value": 3632}, "6": {"effect": -0.15772799862029027, "value": "Millenials"}, "7": {"effect": -2.091138967790124, "value": 309812185}, "8": {"effect": 0.009863378069900864, "value": 0.7415999999999997}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iCN2FMVD1H9PZY6Z8ZNVV')
#   );
# </script>

# %%
shapPlot(19273, model, X_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f8116be8d844> in <module>
# ----> 1 shapPlot(19273, model, X_train)
#
# <ipython-input-23-feaa4308ebc1> in shapPlot(row_num, model, df)
#       1 def shapPlot(row_num, model, df):
#       2     explainer=shap.TreeExplainer(model)
# ----> 3     row=df.loc[[row_num]]
#       4     row_enc=encoder.transform(row)
#       5     shap_values= explainer.shap_values(row_enc)
#
# ~/anaconda3/envs/Unit2/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# ~/anaconda3/envs/Unit2/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1614                     raise ValueError('Cannot index with multidimensional key')
#    1615
# -> 1616                 return self._getitem_iterable(key, axis=axis)
#    1617
#    1618             # nested tuple slicing
#
# ~/anaconda3/envs/Unit2/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1113
#    1114         if self._should_validate_iterable(axis):
# -> 1115             self._has_valid_type(key, axis)
#    1116
#    1117         labels = self.obj._get_axis(axis)
#
# ~/anaconda3/envs/Unit2/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1470                         raise KeyError(
#    1471                             u"None of [{key}] are in the [{axis}]".format(
# -> 1472                                 key=key, axis=self.obj._get_axis_name(axis)))
#    1473                     else:
#    1474
#
# KeyError: 'None of [[19273]] are in the [index]'
